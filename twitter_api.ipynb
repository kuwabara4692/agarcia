# %%
#To install twython package, we will use "pip install twython".
#To run the python package manager known as pip, we change the
#directory in our command prompt. Pip is located in the "Scripts"
#folder. For my local machine here is my pathway for Scripts: C:\Users\ckohler\AppData\Local\Continuum\anaconda3\Scripts

# %%
#Import the necessary libraries for using Twitter's API
import pandas as pd
import requests as rq
from twython import Twython
import json as js
#Link for more information on Twython(twitter api): https://twython.readthedocs.io/en/latest/index.html

# %%
#Define variables we need for connecting to the Twython.
#Link to create app to receive your keys/tokens: https://apps.twitter.com/app
#Click "Create New App", fill out your infomation(free,no cost), then open that app for your key/token information.
app_key=''
secret_app_key=''
app_token=''
secret_app_token=''

#The steps and data seen below were created using my personal twitter app, feel free to use your app in the above parameters

# %%
#We use the twython tool to accesss the Twitter API, matching the parameters
#with our variables assigned above.
twitter=Twython(app_key, secret_app_key, app_token, secret_app_token)

# %%
#Here we validate the Twitter user our app was created under.
twitter.verify_credentials()
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Sun Oct 11 20:07:37 +0000 2015',
#  'default_profile': True,
#  'default_profile_image': False,
#  'description': 'GIS. Environmental Advocate. Geologist. Open-Source GIS enthusiast.',
#  'entities': {'description': {'urls': []}},
#  'favourites_count': 27,
#  'follow_request_sent': False,
#  'followers_count': 25,
#  'following': False,
#  'friends_count': 63,
#  'geo_enabled': False,
#  'has_extended_profile': True,
#  'id': 3930673367,
#  'id_str': '3930673367',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': 'en',
#  'listed_count': 2,
#  'location': '',
#  'name': 'Chris kohler',
#  'notifications': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
# ...

# %%
#View recent activity from your account
twitter.get_home_timeline()
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Apr 12 19:49:57 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 611986351,
#      'id_str': '611986351',
#      'indices': [3, 13],
#      'name': 'Kim Dotcom',
#      'screen_name': 'KimDotcom'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 984519005523230720,
#   'id_str': '984519005523230720',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 131,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Apr 12 16:44:51 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
# ...

# %%
#Search for other twitter users, we assign this function to a varible called "result"
result = twitter.show_user(screen_name='realdonaldtrump')
result
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#  'default_profile': False,
#  'default_profile_image': False,
#  'description': '45th President of the United States of America🇺🇸',
#  'entities': {'description': {'urls': []},
#   'url': {'urls': [{'display_url': 'Instagram.com/realDonaldTrump',
#      'expanded_url': 'http://www.Instagram.com/realDonaldTrump',
#      'indices': [0, 23],
#      'url': 'https://t.co/OMxB0x7xC5'}]}},
#  'favourites_count': 24,
#  'follow_request_sent': False,
#  'followers_count': 50497240,
#  'following': True,
#  'friends_count': 45,
#  'geo_enabled': True,
#  'has_extended_profile': False,
#  'id': 25073877,
#  'id_str': '25073877',
#  'is_translation_enabled': True,
#  'is_translator': False,
#  'lang': 'en',
#  'listed_count': 86431,
#  'location': 'Washington, DC',
#  'name': 'Donald J. Trump',
#  'notifications': False,
#  'profile_background_color': '6D5C18',
# ...

# %%
#We can get the id value can be retreived from "get_user_timeline"
result2 = twitter.show_status(id=984513253735849984)
result2['text']
# Out:
# "What's your favorite GIS apps? Field mapping? Data collection?\nIf other, add it in the comments. And why? What func… https://t.co/ZcBR3JF01f"

# %%
twitter.get_user_timeline(screen_name='realdonaldtrump')
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Apr 12 19:03:57 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/984507430909308929',
#      'indices': [117, 140],
#      'url': 'https://t.co/rkCWxcovmg'}],
#    'user_mentions': []},
#   'favorite_count': 23794,
#   'favorited': False,
#   'geo': None,
#   'id': 984507430909308929,
#   'id_str': '984507430909308929',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 6255,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
# ...
